# %% [markdown]
# #### Table of Contents
#
# - [Holidays Purpose](#first-bullet)
# - [Video](#second-bullet)

# %%
Name=input('Your name is: ')
# Out:
# Your name is: Fabian

# %% [markdown]
# <a class="anchor" id="first-bullet"></a>
# <h1>Holidays Purpose</h1>
# The purpose of this Notebook is to show you...

# %% [markdown]
# ![Seychelles_GettyImages-1169388113.webp](attachment:Seychelles_GettyImages-1169388113.webp)

# %% [markdown]
# <h2><font color="red">Favourite things about the destination</font></h2>
# <ul>
#   <li>The Sea</li>
#   <li>The weather</li>
#   <li>The Food</li>
# </ul>

# %% [markdown]
# <a class="anchor" id="second-bullet"></a>
# [![Image alt text](https://img.youtube.com/vi/RAxwAwGxclo/0.jpg)](https://www.youtube.com/watch?v=RAxwAwGxclo)
